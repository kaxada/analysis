# %%
pip install statsmodels scikit_posthocs scikit-posthocs
# Out:
# Requirement already satisfied: statsmodels in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (0.14.1)
# Requirement already satisfied: scikit_posthocs in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: numpy<2,>=1.18 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.4 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from statsmodels) (24.0)
# Requirement already satisfied: seaborn in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from scikit_posthocs) (0.13.2)
# Requirement already satisfied: matplotlib in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from scikit_posthocs) (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Requirement already satisfied: six in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from matplotlib->scikit_posthocs) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from matplotlib->scikit_posthocs) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from matplotlib->scikit_posthocs) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from matplotlib->scikit_posthocs) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from matplotlib->scikit_posthocs) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kaxada/.virtualenvs/augurlabs/lib/python3.12/site-packages (from matplotlib->scikit_posthocs) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import numpy as np
from scipy.stats import shapiro
from scipy.stats import levene
from scipy.stats import kruskal
import scikit_posthocs as sp

#plt.style.use('seaborn-darkgrid')
sns.set_context('notebook')

# %% [markdown]
# ## Reading tables

# %%
# Reading CSV files
label_table = pd.read_csv("../../data/label_dataset.csv", usecols=lambda column: column != 'Unnamed: 0')
print(label_table.dtypes)

prs_with_git_url = pd.read_csv("prs_with_git_url.csv", usecols=lambda column: column != 'Unnamed: 0')
print(prs_with_git_url.dtypes)

# Joining dataframes
prs_label = pd.merge(prs_with_git_url, label_table, on="repo_id", how="inner")
print(prs_label.dtypes)
print()

# Selecting specific columns
prsSelectedVar = prs_label[['repo_id', 'pull_requests', 'label_name']]
# Out:
# repo_id        int64
# label_name    object
# dtype: object
# rg_name           object
# repo_group_id      int64
# repo_name         object
# repo_id            int64
# repo_git          object
# forked_from       object
# repo_archived    float64
# pull_requests      int64
# dtype: object
# rg_name           object
# repo_group_id      int64
# repo_name         object
# repo_id            int64
# repo_git          object
# forked_from       object
# repo_archived    float64
# pull_requests      int64
# label_name        object
# dtype: object

# %% [markdown]
# ### removing outliers

# %%
# Exclude outliers
def exclude_outliers(data, variable, group_var, sd_threshold=2):
    # Function to filter outliers in a group
    def filter_group(group):
        mean_val = group[variable].mean()
        sd_val = group[variable].std()
        return group[np.abs(group[variable] - mean_val) < sd_threshold * sd_val]
    
    # Apply the filter function to each group and combine the results
    return data.groupby(group_var).apply(filter_group).reset_index(drop=True)

# %%
prsSelectedVar_filtered = exclude_outliers(prsSelectedVar, "pull_requests", "label_name", sd_threshold=2)
# Out:
# /var/folders/xy/1s8thl_55ln_cdl_bngsdtzr0000gn/T/ipykernel_24496/1596213973.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return data.groupby(group_var).apply(filter_group).reset_index(drop=True)

# %% [markdown]
# ## calculating stats to show on plot

# %%
# Calculate stats to show on the plot
stats_df = prsSelectedVar_filtered.groupby('label_name')['pull_requests'].agg(
    average='mean',
    upper_quartile=lambda x: x.quantile(0.75)
).reset_index()

stats_df['label_pos'] = stats_df['upper_quartile'] + 0.5

# %% [markdown]
# ## generating boxplot

# %%
# Set plots style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

# Create a boxplot
ax = sns.boxplot(x='label_name', y='pull_requests', data=prsSelectedVar_filtered, palette="Set2", dodge=True, hue="label_name")

# Add mean values as text on the plot
for index, row in stats_df.iterrows():
    ax.text(
        x=index, 
        y=row['label_pos'], 
        s=f"Mean: {row['average']:.2f}", 
        color='black', 
        ha="center", 
        size=12
    )

# Set plot title and labels
ax.set_title('Box Plot with Descriptive Statistics', fontsize=14)
ax.set_xlabel('Label Name', fontsize=12)
ax.set_ylabel('Pull Requests', fontsize=12)

# Making plot easier to read
sns.despine(trim=True)
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# # testing normality and variance homogeneity

# %% [markdown]
# ## 1) Distribuation visualizations - Density plot

# %%
# Create a density plot
plt.figure(figsize=(8, 8))
#sns.kdeplot(data=commitSelectedVar, x='commits', hue='label_name', fill=True, common_norm=False, alpha=0.5, palette='coolwarm')
sns.kdeplot(data=prsSelectedVar, x='pull_requests', hue='label_name', fill=True, common_norm=False, alpha=0.5, palette='viridis')

plt.title('Histogram of Contributions by Repo Label')
plt.xlabel('Number of Pull Requests')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## Kruskal-Wallis H test to test whether there is a significant difference among pairs of groups

# %%
groups = [group['pull_requests'].values for name, group in prsSelectedVar.groupby('label_name')]

# Perform Kruskal-Wallis H Test
stat, p = kruskal(*groups)
print(f'Kruskal-Wallis H Test Statistic: {stat}, P-value: {p}')
# Out:
# Kruskal-Wallis H Test Statistic: 55.79954840631875, P-value: 7.643319556707599e-13

# %% [markdown]
# ## Dunn's test to conduct post-hoc test for examining the differience between each pair of groups.

# %%
# Conduct Dunn's Test
dunn_test_result = sp.posthoc_dunn(prsSelectedVar, val_col='pull_requests', group_col='label_name', p_adjust='fdr_bh')

print(dunn_test_result)
# Out:
#                    grads  incubating       sandbox
# grads       1.000000e+00    0.048834  1.652552e-10
# incubating  4.883414e-02    1.000000  2.341731e-06
# sandbox     1.652552e-10    0.000002  1.000000e+00
